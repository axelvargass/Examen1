# %% [markdown]
# <a href="https://colab.research.google.com/github/axelvargass/Examen1/blob/main/Lastmile_serving_costumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías pandas numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Lectura de archivo tipo .csv
costumer = pd.read_csv('lastmile_delivery_operations_mit_lift_lab_serving_customer.csv')
costumer
# Out:
#                         _child_record_id  \
# 0   12645bc3-33b6-4cc0-9c8e-9d8e6f35aa01
# 1   be0fc402-769c-41f8-90f1-1b0c9f151e7a
# 2   634bbd94-8159-4733-973a-36ab89fb95d4
# 3   cf8e05ea-0af9-4a66-9d8b-27c0cf572236
# 4   a1ff05ef-fe15-472e-ad6d-537c951afce4
# 5   9e96f584-f5b2-4e7d-a754-a34fc89d5139
# 6   531eb119-cab7-4ba9-8a25-489e91ec2a5a
# 7   17995e32-9ed3-4a27-8da3-b4e1d942ad36
# 8   009bf340-321a-4739-84b4-d80029770d10
# 9   c78336c3-d0ab-4e08-bc2e-f15af41f76fb
# 10  a616737c-bcb2-4ad0-a82a-4ca917fab0fc
# 11  8e4d79db-4fa9-4c83-ba72-88b109a2a71b
# 12  89943c66-9129-458f-a295-6ecc61b4dfa2
# 13  044b47df-e630-4ca7-ac15-2ba322760aae
# 14  98e21e5a-b7cc-4314-813e-b4cd016fbe67
# 15  eb6170a1-74f1-4dca-ba9b-53614e8ce1e9
# 16  83fd3b7d-52b4-45d0-8f25-df98b6229aed
# 17  e45b69e0-5250-403b-a1f4-54daf1427ff8
# 18  7c0e3d41-b490-4940-8286-15fa3d8a5726
# 19  1788e007-9b6b-4cc4-aaf7-35d1b8143f32
# 20  c98cae40-7553-4755-a0f8-a51fbe275d12
# 21  348702bf-ec37-436e-ba06-fe8e54abab13
# ...

# %%
#Filtro de columnas para cualitativas
cualitativas = costumer.iloc[:,[0,1,2,3,5,6,7,8,13,17,21,22,23,25]]

# %%
#Filtro de columnas para cuantitativas
cuantitativas = costumer.iloc[:,[4,9,11,12,14,15,16,18,19,20,24,26]]

# %%
#Corroboramos valores nulos
valores_nulos = cualitativas.isnull().sum()
valores_nulos
# Out:
# _child_record_id                           0
# _record_id                                 0
# _parent_id                                 0
# _title                                     0
# _created_at                                0
# _updated_at                                0
# _created_by                                0
# _updated_by                                0
# _changeset_id                              0
# name_of_the_store                          0
# picture_cargo_being_delivered             10
# picture_cargo_being_delivered_captions    33
# picture_cargo_being_delivered_urls        10
# trolley_in_use                             0
# dtype: int64

# %%
#Limpiamos Valores nulos de cualitativos
filtrocualitativos = cualitativas.fillna(method='ffill')

# %%
#Corroboramos valores nulos de Cualitativos para limpiarlos
valores_nulos = filtrocualitativos.isnull().sum()
valores_nulos
# Out:
# _child_record_id                          0
# _record_id                                0
# _parent_id                                0
# _title                                    0
# _created_at                               0
# _updated_at                               0
# _created_by                               0
# _updated_by                               0
# _changeset_id                             0
# name_of_the_store                         0
# picture_cargo_being_delivered             0
# picture_cargo_being_delivered_captions    0
# picture_cargo_being_delivered_urls        0
# trolley_in_use                            0
# dtype: int64

# %%
#Limpiamos los valores nulos de Cuantitativas
filtrocuantitativas = cuantitativas.fillna(round(cuantitativas.mean(),1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
#Corroboramos valores nulos de Cualitativos para limpiarlos
valores_nulos_cuantitativos = filtrocuantitativas.isnull().sum()
valores_nulos_cuantitativos
# Out:
# _version                           0
# _index                             0
# _latitude                          0
# _longitude                         0
# _created_duration                  0
# _updated_duration                  0
# _edited_duration                   0
# entering_the_store                 0
# number_of_customers_in_store       0
# number_of_suppliers_in_store       0
# number_of_cases_boxes_delivered    0
# leaving_the_store                  0
# dtype: int64

# %%
#Método de IQR
y = filtrocuantitativas
percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido _version                             1.000000
# _index                               0.000000
# _latitude                           19.118961
# _longitude                         -98.181767
# _created_duration                    0.000000
# _updated_duration                  177.250000
# _edited_duration                   172.000000
# number_of_customers_in_store         5.000000
# number_of_suppliers_in_store         3.500000
# number_of_cases_boxes_delivered     12.000000
# dtype: float64
# Limite inferior permitido _version                            1.000000
# _index                              0.000000
# _latitude                          18.935810
# _longitude                        -98.319111
# _created_duration                   0.000000
# _updated_duration                 -40.750000
# _edited_duration                  -32.000000
# number_of_customers_in_store       -3.000000
# number_of_suppliers_in_store       -0.500000
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr = filtrocuantitativas[(y <= Limite_Superior_iqr)&(y >= Limite_Inferior_iqr)]
data_clean_iqr
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#     _version  _index  _latitude  _longitude  _created_duration  \
# 0          1       0  19.059667  -98.233864                NaN
# 1          1       0  19.053049  -98.229422                NaN
# 2          1       0  19.051740  -98.232677                NaN
# 3          1       0  19.052990  -98.233991                NaN
# 4          1       0  19.055389  -98.230130                NaN
# 5          1       0  19.053104  -98.227161                NaN
# 6          1       0  19.045903  -98.203487                0.0
# 7          1       0  19.023488  -98.203281                0.0
# 8          1       0  19.046459  -98.193698                0.0
# ...

# %%
#Unimos ambos dataframes ya que estan limpios
datos_limpios = pd.concat([filtrocuantitativas,filtrocualitativos],axis=1)
datos_limpios
# Out:
#     _version  _index  _latitude  _longitude  _created_duration  \
# 0          1       0  19.059667  -98.233864                 61
# 1          1       0  19.053049  -98.229422                 80
# 2          1       0  19.051740  -98.232677                 25
# 3          1       0  19.052990  -98.233991                 41
# 4          1       0  19.055389  -98.230130                 76
# 5          1       0  19.053104  -98.227161                 53
# 6          1       0  19.045903  -98.203487                  0
# 7          1       0  19.023488  -98.203281                  0
# 8          1       0  19.046459  -98.193698                  0
# 9          1       0  19.065868  -98.310562                624
# 10         1       0  19.064508  -98.311303                167
# 11         1       0  19.047385  -98.204255                  0
# 12         1       0  19.048819  -98.200050                  0
# 13         1       0  18.999429  -98.274060                  0
# ...

# %%
#Convertir dataframe a CSV
datos_limpios.to_csv("Lastmile_serving_costumer.csv")
#Descargar archivo filtrado en csv
from google.colab import files


files.download("Lastmile_serving_costumer.csv")
